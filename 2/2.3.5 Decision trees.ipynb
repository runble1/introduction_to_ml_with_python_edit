# %% [markdown]
# # 決定木
# クラス分類と回帰タスクに広く用いられているモデル
# Yes/Noで答えられる質問で構成された階層的な木構造を学習する

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mglearn
from IPython.display import display
from sklearn.model_selection import train_test_split
# %matplotlib notebook
# %matplotlib inline

# %% [markdown]
# ## 2.3.5.1 決定木の構築

# %%
# two_moonデータセットは、75のデータポイントをもつ
# 深さが１の場合、
mglearn.plots.plot_tree_progressive()

# %% [markdown]
# ## 2.3.5.2 決定木の複雑さの制御

# %% [markdown]
# ## 2.3.5.3 決定木の解析

# %% [markdown]
# ## 2.3.5.4 決定木の特徴量の重要性

# %% [markdown]
# ## 2.3.5.5 長所、短所、パラメータ
