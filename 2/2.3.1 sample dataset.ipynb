# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mglearn
from IPython.display import display
# %matplotlib notebook
# %matplotlib inline

# %% [markdown]
# # 2.3.1 サンプルデータセット

# %%
# 今回使うforgeデータセットのデータポイントを散布図で表示
X, y = mglearn.datasets.make_forge()
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.legend(["Class 0", "Class 1"], loc=4)
plt.xlabel("First feature")
plt.ylabel("Second feature")
print("X.shape: {}".format(X.shape))
# Out:
# <img src="data:image/png;base64,..." width="640">
# X.shape: (26, 2)

# %%
# 特徴量をx軸、ターゲットをy軸に
X, y = mglearn.datasets.make_wave(n_samples=40)
plt.plot(X, y, 'o')
plt.ylim(-3, 3)
plt.xlabel("Feature")
plt.ylabel("Target")

# %%
# cancerデータセット
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
print("cancer.keys(): \n{}".format(cancer.keys()))
# Out:
# cancer.keys():
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %%
# 30の特徴量を持つ569のデータポイントで構成
cancer.data.shape
# Out:
# (569, 30)

# %%
cancer.target_names
# Out:
# array(['malignant', 'benign'],
#       dtype='<U9')

# %%
np.bincount(cancer.target)
# Out:
# array([212, 357])

# %%
# 569のうち357が良性、２１２が悪性
{n: v for n, v in zip(cancer.target_names, np.bincount(cancer.target))}
# Out:
# {'benign': 357, 'malignant': 212}

# %%
# 個々の特徴量の意味
cancer.feature_names
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension'],
#       dtype='<U23')

# %%
# boston_housingデータセット
# 1970年台のボストン近郊の住宅地の住宅価格の中央値を
# 犯罪率、チャールズ川からの距離、高速道路への利便性などから予測するもの
from sklearn.datasets import load_boston
boston = load_boston()
boston.data.shape
# Out:
# (506, 13)

# %%
# DESCR属性にデータセットの詳細がわかる
# 特徴量間の積：交互作用もみる→特徴量エンジニアリング
# 13の特徴量に、13の特徴量から2つの特徴量を選ぶ重複ありの組み合わせ91を足したもの
X, y = mglearn.datasets.load_extended_boston()
X.shape
# Out:
# (506, 104)
